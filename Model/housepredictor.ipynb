# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)

# %%
df1=pd.read_csv('C:\\Users\\RIJUL GULATI\\Downloads\\archive\\MagicBricks.csv') 
df1.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df1.shape
# Out:
# (1259, 11)

# %%
df1.groupby('Locality')['Locality'].agg('count')
# Out:
# Locality
# APL Builder Floor, Greater Kailash 1                                                                                                                                                                                                                                                                                                       2
# Aashirwaad Chowk, Dwarka                                                                                                                                                                                                                                                                                                                   6
# ...

# %%
df1.groupby('Type')['Type'].agg('count')
# Out:
# Type
# Apartment        593
# Builder_Floor    661
# Name: Type, dtype: int64

# %%
df2=df1.drop(['Status','Type','Furnishing'],axis='columns')
df2.head()
# Out:
#     Area  BHK  Bathroom                                           Locality  \
# 0  800.0    3       2.0                                   Rohini Sector 25
# 1  750.0    2       2.0             J R Designers Floors, Rohini Sector 24
# 2  950.0    2       2.0                Citizen Apartment, Rohini Sector 13
# 3  600.0    2       2.0                                   Rohini Sector 24
# 4  650.0    2       2.0  Rohini Sector 24 carpet area 650 sqft status R...
#
#    Parking     Price   Transaction  Per_Sqft
# 0      1.0   6500000  New_Property       NaN
# 1      1.0   5000000  New_Property    6667.0
# 2      1.0  15500000        Resale    6667.0
# 3      1.0   4200000        Resale    6667.0
# 4      1.0   6200000  New_Property    6667.0

# %%
df2.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Locality         0
# Parking         33
# Price            0
# Transaction      0
# Per_Sqft       241
# dtype: int64

# %%
df2['Per_Sqft'].fillna(df2['Per_Sqft'].median(), inplace=True)
# Out:
# C:\Users\RIJUL GULATI\AppData\Local\Temp\ipykernel_1620\765632384.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Per_Sqft'].fillna(df2['Per_Sqft'].median(), inplace=True)

# %%
df2
# Out:
#          Area  BHK  Bathroom  \
# 0       800.0    3       2.0
# 1       750.0    2       2.0
# 2       950.0    2       2.0
# 3       600.0    2       2.0
# 4       650.0    2       2.0
# ...       ...  ...       ...
# 1254   4118.0    4       5.0
# 1255   1050.0    3       2.0
# 1256    875.0    3       3.0
# 1257    990.0    2       2.0
# 1258  11050.0    3       3.0
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
# ...                                                 ...      ...       ...
# 1254                                  Chittaranjan Park      3.0  55000000
# ...

# %%
df2.isnull().sum()
# Out:
# Area            0
# BHK             0
# Bathroom        2
# Locality        0
# Parking        33
# Price           0
# Transaction     0
# Per_Sqft        0
# dtype: int64

# %%
df2['Parking'].fillna(df2['Parking'].median(), inplace=True)  #do backfill or forward fill
df2['Bathroom'].fillna(df2['Bathroom'].median(), inplace=True)
# Out:
# C:\Users\RIJUL GULATI\AppData\Local\Temp\ipykernel_1620\2620867837.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Parking'].fillna(df2['Parking'].median(), inplace=True)  #do backfill or forward fill
# C:\Users\RIJUL GULATI\AppData\Local\Temp\ipykernel_1620\2620867837.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df2.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Locality       0
# Parking        0
# Price          0
# Transaction    0
# Per_Sqft       0
# dtype: int64

# %%
uni=df2['Locality'].unique()
print(uni)
# Out:
# ['Rohini Sector 25' 'J R Designers Floors, Rohini Sector 24'
#  'Citizen Apartment, Rohini Sector 13' 'Rohini Sector 24'
#  'Rohini Sector 24 carpet area 650 sqft status Ready to Move floor 4 out of 4 floors transaction New Property furnishing Semi-Furnished facing East overlooking Garden/Park, Main Road car parking 1 Open bathroom 2 balcony 1 ownership Freehold Newly Constructed Property Newly Constructed Property East Facing Property 2BHK Newly build property for Sale. A House is waiting for a Friendly Family to make it a lovely home.So please come and make his house feel alive once again. read more Contact Agent View Phone No. Share Feedback Garima properties Certified Agent Trusted by Users Genuine Listings Market Knowledge'
#  'Delhi Homes, Rohini Sector 24' 'Rohini Sector 21' 'Rohini Sector 22'
#  'Rohini Sector 20'
# ...

# %%
df2['Locality_length'] = df2['Locality'].str.len()
print(df2[['Locality_length','Locality']])
# Out:
#       Locality_length                                           Locality
# 0                  16                                   Rohini Sector 25
# 1                  38             J R Designers Floors, Rohini Sector 24
# 2                  35                Citizen Apartment, Rohini Sector 13
# 3                  16                                   Rohini Sector 24
# 4                 612  Rohini Sector 24 carpet area 650 sqft status R...
# ...               ...                                                ...
# 1254               17                                  Chittaranjan Park
# 1255               17                                  Chittaranjan Park
# 1256               17                                  Chittaranjan Park
# 1257               25                          Chittaranjan Park Block A
# 1258               17                                  Chittaranjan Park
#
# [1259 rows x 2 columns]

# %%
unique_locations = df2['Locality'].unique()

# Create a DataFrame with unique locations and their lengths
unique_locations_df = pd.DataFrame({'Locality': unique_locations})
unique_locations_df['Locality_len'] = unique_locations_df['Locality'].str.len()
print(unique_locations_df)
# Out:
#                                               Locality  Locality_len
# 0                                     Rohini Sector 25            16
# 1               J R Designers Floors, Rohini Sector 24            38
# 2                  Citizen Apartment, Rohini Sector 13            35
# 3                                     Rohini Sector 24            16
# 4    Rohini Sector 24 carpet area 650 sqft status R...           612
# ..                                                 ...           ...
# 360          Arya Chittaranjan Park, Chittaranjan Park            41
# 361  Chittaranjan Park carpet area 1200 sqft status...           534
# 362  Chittaranjan Park carpet area 270 sqyrd status...           536
# 363                             Nehru Enclave, Kalkaji            22
# 364                          Chittaranjan Park Block A            25
#
# [365 rows x 2 columns]

# %%
unique_locations = df2['Locality'].unique()

# Create a DataFrame with unique locations and their lengths
unique_locations_df = pd.DataFrame({'Locality': unique_locations})
unique_locations_df['Locality_len'] = unique_locations_df['Locality'].str.len()

# Truncate localities that are longer than 200 characters to 40 characters
unique_locations_df['Locality'] = unique_locations_df['Locality'].apply(
    lambda x: x if len(x) <= 200 else x[:40]
)
unique_locations_df['Locality_len'] = unique_locations_df['Locality'].str.len()

print(unique_locations_df)
# Out:
#                                       Locality  Locality_len
# 0                             Rohini Sector 25            16
# 1       J R Designers Floors, Rohini Sector 24            38
# 2          Citizen Apartment, Rohini Sector 13            35
# 3                             Rohini Sector 24            16
# 4     Rohini Sector 24 carpet area 650 sqft st            40
# ..                                         ...           ...
# 360  Arya Chittaranjan Park, Chittaranjan Park            41
# 361   Chittaranjan Park carpet area 1200 sqft             40
# 362   Chittaranjan Park carpet area 270 sqyrd             40
# 363                     Nehru Enclave, Kalkaji            22
# 364                  Chittaranjan Park Block A            25
#
# [365 rows x 2 columns]

# %%
unique_locations = df2['Locality'].unique()

# Create a DataFrame with unique locations and their lengths
unique_locations_df = pd.DataFrame({'Locality': unique_locations})

# Remove specific words
unique_locations_df['Locality'] = unique_locations_df['Locality'].str.replace('carpet area', '', case=False)
unique_locations_df['Locality'] = unique_locations_df['Locality'].str.replace('sqft', '', case=False)

# Truncate localities that are longer than 200 characters to 40 characters
unique_locations_df['Locality'] = unique_locations_df['Locality'].apply(
    lambda x: x if len(x) <= 200 else x[:18]
)

# Recalculate the lengths
unique_locations_df['Locality_len'] = unique_locations_df['Locality'].str.len()

print(unique_locations_df)
# Out:
#                                       Locality  Locality_len
# 0                             Rohini Sector 25            16
# 1       J R Designers Floors, Rohini Sector 24            38
# 2          Citizen Apartment, Rohini Sector 13            35
# 3                             Rohini Sector 24            16
# 4                           Rohini Sector 24              18
# ..                                         ...           ...
# 360  Arya Chittaranjan Park, Chittaranjan Park            41
# 361                         Chittaranjan Park             18
# 362                         Chittaranjan Park             18
# 363                     Nehru Enclave, Kalkaji            22
# 364                  Chittaranjan Park Block A            25
#
# [365 rows x 2 columns]

# %%
unique_locations_df['Locality'].unique()
# Out:
# array(['Rohini Sector 25', 'J R Designers Floors, Rohini Sector 24',
#        'Citizen Apartment, Rohini Sector 13', 'Rohini Sector 24',
#        'Rohini Sector 24  ', 'Delhi Homes, Rohini Sector 24',
#        'Rohini Sector 21', 'Rohini Sector 22', 'Rohini Sector 20',
#        'Rohini Sector 8 Ho', 'Rohini Sector 25  ', 'Rohini Sector 16',
#        'Rohini Sector 14', 'Mayur Apartment, Rohini Sector 9',
#        'Vijay Vihar, Rohini', 'Rohini Sector 18  ',
#        'Prashant Vihar, Rohini', 'Rohini Sector 5',
#        'Sanskriti Apartment, Rohini Sector 28', 'Rohini Sector 19',
#        'Lajpat Nagar 2', 'Lajpat Nagar 1', 'Lajpat Nagar',
#        'Vikram Vihar, Lajpat Nagar', 'Lajpat Nagar 4', 'Lajpat Nagar 3',
#        'Dayanand Colony, L', 'Amar Colony, Lajpat Nagar',
#        'DDA Flats Sector 14, Dwarka Sector 14',
#        'Siddhartha Heights, Dwarka Sector 24',
#        'MTNL Employees House Welfare Society, Dwarka Sector 24',
#        'Delhi Homes Yojana, Dwarka Sector 24',
# ...

# %%
df2['Locality'] = df2['Locality'].str.replace('carpet area', '', case=False)
df2['Locality'] = df2['Locality'].str.replace('sqft', '', case=False)

# Truncate localities that are longer than 200 characters to 40 characters
df2['Locality'] = df2['Locality'].apply(
    lambda x: x if len(x) <= 200 else x[:18]
)
print(df2)
# Out:
#          Area  BHK  Bathroom                                Locality  Parking  \
# 0       800.0    3       2.0                        Rohini Sector 25      1.0
# 1       750.0    2       2.0  J R Designers Floors, Rohini Sector 24      1.0
# 2       950.0    2       2.0     Citizen Apartment, Rohini Sector 13      1.0
# 3       600.0    2       2.0                        Rohini Sector 24      1.0
# 4       650.0    2       2.0                      Rohini Sector 24        1.0
# ...       ...  ...       ...                                     ...      ...
# 1254   4118.0    4       5.0                       Chittaranjan Park      3.0
# 1255   1050.0    3       2.0                       Chittaranjan Park      3.0
# 1256    875.0    3       3.0                       Chittaranjan Park      3.0
# 1257    990.0    2       2.0               Chittaranjan Park Block A      1.0
# 1258  11050.0    3       3.0                       Chittaranjan Park      1.0
#
# ...

# %%
df2['Locality'].unique()
# Out:
# array(['Rohini Sector 25', 'J R Designers Floors, Rohini Sector 24',
#        'Citizen Apartment, Rohini Sector 13', 'Rohini Sector 24',
#        'Rohini Sector 24  ', 'Delhi Homes, Rohini Sector 24',
#        'Rohini Sector 21', 'Rohini Sector 22', 'Rohini Sector 20',
#        'Rohini Sector 8 Ho', 'Rohini Sector 25  ', 'Rohini Sector 16',
#        'Rohini Sector 14', 'Mayur Apartment, Rohini Sector 9',
#        'Vijay Vihar, Rohini', 'Rohini Sector 18  ',
#        'Prashant Vihar, Rohini', 'Rohini Sector 5',
#        'Sanskriti Apartment, Rohini Sector 28', 'Rohini Sector 19',
#        'Lajpat Nagar 2', 'Lajpat Nagar 1', 'Lajpat Nagar',
#        'Vikram Vihar, Lajpat Nagar', 'Lajpat Nagar 4', 'Lajpat Nagar 3',
#        'Dayanand Colony, L', 'Amar Colony, Lajpat Nagar',
#        'DDA Flats Sector 14, Dwarka Sector 14',
#        'Siddhartha Heights, Dwarka Sector 24',
#        'MTNL Employees House Welfare Society, Dwarka Sector 24',
#        'Delhi Homes Yojana, Dwarka Sector 24',
# ...

# %%
df3=df2.drop(['Locality_length'],axis='columns')
df3.head()
# Out:
#     Area  BHK  Bathroom                                Locality  Parking  \
# 0  800.0    3       2.0                        Rohini Sector 25      1.0
# 1  750.0    2       2.0  J R Designers Floors, Rohini Sector 24      1.0
# 2  950.0    2       2.0     Citizen Apartment, Rohini Sector 13      1.0
# 3  600.0    2       2.0                        Rohini Sector 24      1.0
# 4  650.0    2       2.0                      Rohini Sector 24        1.0
#
#       Price   Transaction  Per_Sqft
# 0   6500000  New_Property   11291.5
# 1   5000000  New_Property    6667.0
# 2  15500000        Resale    6667.0
# 3   4200000        Resale    6667.0
# 4   6200000  New_Property    6667.0

# %%
df3
# Out:
#          Area  BHK  Bathroom                                Locality  Parking  \
# 0       800.0    3       2.0                        Rohini Sector 25      1.0
# 1       750.0    2       2.0  J R Designers Floors, Rohini Sector 24      1.0
# 2       950.0    2       2.0     Citizen Apartment, Rohini Sector 13      1.0
# 3       600.0    2       2.0                        Rohini Sector 24      1.0
# 4       650.0    2       2.0                      Rohini Sector 24        1.0
# ...       ...  ...       ...                                     ...      ...
# 1254   4118.0    4       5.0                       Chittaranjan Park      3.0
# 1255   1050.0    3       2.0                       Chittaranjan Park      3.0
# 1256    875.0    3       3.0                       Chittaranjan Park      3.0
# 1257    990.0    2       2.0               Chittaranjan Park Block A      1.0
# 1258  11050.0    3       3.0                       Chittaranjan Park      1.0
#
# ...

# %%
df3['Locality'].unique()
# Out:
# array(['Rohini Sector 25', 'J R Designers Floors, Rohini Sector 24',
#        'Citizen Apartment, Rohini Sector 13', 'Rohini Sector 24',
#        'Rohini Sector 24  ', 'Delhi Homes, Rohini Sector 24',
#        'Rohini Sector 21', 'Rohini Sector 22', 'Rohini Sector 20',
#        'Rohini Sector 8 Ho', 'Rohini Sector 25  ', 'Rohini Sector 16',
#        'Rohini Sector 14', 'Mayur Apartment, Rohini Sector 9',
#        'Vijay Vihar, Rohini', 'Rohini Sector 18  ',
#        'Prashant Vihar, Rohini', 'Rohini Sector 5',
#        'Sanskriti Apartment, Rohini Sector 28', 'Rohini Sector 19',
#        'Lajpat Nagar 2', 'Lajpat Nagar 1', 'Lajpat Nagar',
#        'Vikram Vihar, Lajpat Nagar', 'Lajpat Nagar 4', 'Lajpat Nagar 3',
#        'Dayanand Colony, L', 'Amar Colony, Lajpat Nagar',
#        'DDA Flats Sector 14, Dwarka Sector 14',
#        'Siddhartha Heights, Dwarka Sector 24',
#        'MTNL Employees House Welfare Society, Dwarka Sector 24',
#        'Delhi Homes Yojana, Dwarka Sector 24',
# ...

# %% [markdown]
# FEATURE ENGINEERING

# %%
len(df3.Locality.unique())
# Out:
# 355

# %%
df3.Locality=df3.Locality.apply(lambda x:x.strip())
lstats=df3.groupby('Locality')['Locality'].agg('count').sort_values(ascending=False)
lstats
# Out:
# Locality
# Lajpat Nagar 3                             34
# Lajpat Nagar 2                             33
# J R Designers Floors, Rohini Sector 24     31
# Kailash Colony, Greater Kailash            30
# Yamuna Vihar, Shahdara                     29
#                                            ..
# Sheikh Sarai                                1
# Shivnam Apartment, Shahdara                 1
# Shri Agrasen Apartment, Dwarka Sector 7     1
# Shubh Niketan, Paschim Vihar                1
# Sitaram Bazar, Chandni Chowk                1
# Name: Locality, Length: 352, dtype: int64

# %%
len(lstats[lstats<=10])
# Out:
# 324

# %%
lstatslessthan1=lstats[lstats==1]
lstatslessthan1
# Out:
# Locality
# Ahinsha Vatika, Ram Nagar, Shahdara                     1
# Anekant Apartment, Vasundhara Enclave                   1
# Anupam Enclave, Saket                                   1
# Apna Apartments, Savitri Nagar Village, Sheikh Sarai    1
# Aravali Tower, Chhattarpur                              1
#                                                        ..
# Sheikh Sarai                                            1
# Shivnam Apartment, Shahdara                             1
# Shri Agrasen Apartment, Dwarka Sector 7                 1
# Shubh Niketan, Paschim Vihar                            1
# Sitaram Bazar, Chandni Chowk                            1
# Name: Locality, Length: 179, dtype: int64

# %%
df3.Locality=df3.Locality.apply(lambda x:'other' if x in lstatslessthan1 else x)
len(df3.Locality.unique())
# Out:
# 174

# %%
df3
# Out:
#          Area  BHK  Bathroom                                Locality  Parking  \
# 0       800.0    3       2.0                        Rohini Sector 25      1.0
# 1       750.0    2       2.0  J R Designers Floors, Rohini Sector 24      1.0
# 2       950.0    2       2.0                                   other      1.0
# 3       600.0    2       2.0                        Rohini Sector 24      1.0
# 4       650.0    2       2.0                        Rohini Sector 24      1.0
# ...       ...  ...       ...                                     ...      ...
# 1254   4118.0    4       5.0                       Chittaranjan Park      3.0
# 1255   1050.0    3       2.0                       Chittaranjan Park      3.0
# 1256    875.0    3       3.0                       Chittaranjan Park      3.0
# 1257    990.0    2       2.0                                   other      1.0
# 1258  11050.0    3       3.0                       Chittaranjan Park      1.0
#
# ...

# %% [markdown]
# outliner removal

# %%
df3[df3.Area/df3.BHK<300].head()
# Out:
#          Area  BHK  Bathroom          Locality  Parking     Price  \
# 0    800.0000    3       2.0  Rohini Sector 25      1.0   6500000
# 11   870.0000    3       2.0  Rohini Sector 25      1.0   7700000
# 14   344.4448    2       2.0             other      1.0   3310000
# 16   550.0000    2       2.0  Rohini Sector 22      1.0   4500000
# 17  1100.0000    4       3.0             other      1.0  17000000
#
#      Transaction  Per_Sqft
# 0   New_Property   11291.5
# 11  New_Property    6154.0
# 14        Resale    6154.0
# 16  New_Property    6154.0
# 17  New_Property    6154.0

# %%
df3.shape
# Out:
# (1259, 8)

# %%
df4=df3[~(df3.Area/df3.BHK<300)]
df4.shape
# Out:
# (1083, 8)

# %%
df4.Per_Sqft.describe()
# Out:
# count      1083.000000
# mean      14974.536011
# std       19161.561326
# min        1259.000000
# 25%        7171.500000
# 50%       11291.500000
# 75%       15500.000000
# max      183333.000000
# Name: Per_Sqft, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('Locality'):
        m = np.mean(subdf.Per_Sqft)
        st = np.std(subdf.Per_Sqft)
        reduced_df = subdf[(subdf.Per_Sqft>(m-st)) & (subdf.Per_Sqft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df5 = remove_pps_outliers(df4)
df5.shape
# Out:
# (717, 8)

# %%
def plot_scatter_chart(df,location):
    bhk2 = df[(df.Locality==location) & (df.BHK==2.0)]
    bhk3 = df[(df.Locality==location) & (df.BHK==3.0)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.Area,bhk2.Price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.Area,bhk3.Price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
plot_scatter_chart(df5,'Chittaranjan Park')

# %%
dummies = pd.get_dummies(df5.Locality)
dummies.head(3)
# Out:
#    Abhimanyu Apartments, Vasundhara Enclave  \
# 0                                      True
# 1                                     False
# 2                                     False
#
#    Abul Fazal Enclave Part-II, Okhla  Alaknanda  Amar Colony, Lajpat Nagar  \
# 0                              False      False                      False
# 1                               True      False                      False
# 2                              False       True                      False
#
#    Andheria Mor, Mehrauli  Arjun Nagar, Safdarjung Enclave  \
# 0                   False                            False
# 1                   False                            False
# 2                   False                            False
#
#    Ashirwad Apartments, Dwarka  Ashirwad Apartments, Dwarka Sector 12  \
# 0                        False                                  False
# 1                        False                                  False
# ...

# %%
dummies = pd.get_dummies(df5.Locality)
dummies
# Out:
#      Abhimanyu Apartments, Vasundhara Enclave  \
# 0                                        True
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 712                                     False
# 713                                     False
# 714                                     False
# 715                                     False
# 716                                     False
#
#      Abul Fazal Enclave Part-II, Okhla  Alaknanda  Amar Colony, Lajpat Nagar  \
# 0                                False      False                      False
# 1                                 True      False                      False
# 2                                False       True                      False
# 3                                False       True                      False
# ...

# %%
df6=pd.concat([df5,dummies.drop('other',axis='columns')],axis='columns')
df6
# Out:
#        Area  BHK  Bathroom                                  Locality  Parking  \
# 0    1350.0    4       4.0  Abhimanyu Apartments, Vasundhara Enclave      1.0
# 1     750.0    2       2.0         Abul Fazal Enclave Part-II, Okhla      1.0
# 2    1400.0    3       2.0                                 Alaknanda      1.0
# 3    1100.0    2       2.0                                 Alaknanda      2.0
# 4    1200.0    2       2.0                                 Alaknanda      2.0
# ..      ...  ...       ...                                       ...      ...
# 712  1300.0    3       2.0                                     other      1.0
# 713  6000.0    5       5.0                                     other      3.0
# 714  1700.0    3       3.0                                     other      1.0
# 715  1250.0    3       3.0                                     other      1.0
# 716   990.0    2       2.0                                     other      1.0
#
# ...

# %%
df7=df6.drop('Locality',axis='columns')
df7
# Out:
#        Area  BHK  Bathroom  Parking      Price   Transaction  Per_Sqft  \
# 0    1350.0    4       4.0      1.0   10500000        Resale   11291.5
# 1     750.0    2       2.0      1.0    3800000        Resale   10320.0
# 2    1400.0    3       2.0      1.0   19000000        Resale   12500.0
# 3    1100.0    2       2.0      2.0   15000000        Resale   12500.0
# 4    1200.0    2       2.0      2.0   17500000        Resale   12500.0
# ..      ...  ...       ...      ...        ...           ...       ...
# 712  1300.0    3       2.0      1.0   13500000        Resale   18000.0
# 713  6000.0    5       5.0      3.0  180000000  New_Property   30000.0
# 714  1700.0    3       3.0      1.0   36500000        Resale   25000.0
# 715  1250.0    3       3.0      1.0   25500000  New_Property   11291.5
# 716   990.0    2       2.0      1.0   11500000        Resale   12916.0
#
#      Abhimanyu Apartments, Vasundhara Enclave  \
# 0                                        True
# ...

# %%
X=df7.drop(['Price','Transaction'],axis='columns')
# X=df7.drop('Transaction',axis='columns')

X.head()
X
# Out:
#        Area  BHK  Bathroom  Parking  Per_Sqft  \
# 0    1350.0    4       4.0      1.0   11291.5
# 1     750.0    2       2.0      1.0   10320.0
# 2    1400.0    3       2.0      1.0   12500.0
# 3    1100.0    2       2.0      2.0   12500.0
# 4    1200.0    2       2.0      2.0   12500.0
# ..      ...  ...       ...      ...       ...
# 712  1300.0    3       2.0      1.0   18000.0
# 713  6000.0    5       5.0      3.0   30000.0
# 714  1700.0    3       3.0      1.0   25000.0
# 715  1250.0    3       3.0      1.0   11291.5
# 716   990.0    2       2.0      1.0   12916.0
#
#      Abhimanyu Apartments, Vasundhara Enclave  \
# 0                                        True
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 712                                     False
# ...

# %%
# df7.columns.tolist()
X.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Parking', 'Per_Sqft',
#        'Abhimanyu Apartments, Vasundhara Enclave',
#        'Abul Fazal Enclave Part-II, Okhla', 'Alaknanda',
#        'Amar Colony, Lajpat Nagar', 'Andheria Mor, Mehrauli',
#        ...
#        'Sunny Valley Apartments, Dwarka', 'The Amaryllis, Karol Bagh',
#        'The Leela Sky Villas, Patel Nagar', 'Uttam Nagar', 'Vasant Kunj',
#        'Vasant Kunj Sector C', 'Vasundhara Enclave',
#        'Vikram Vihar, Lajpat Nagar', 'Vinoba Puri, Lajpat Nagar',
#        'Yamuna Vihar, Shahdara'],
#       dtype='object', length=116)

# %%
y=df7.Price
y.head()
# Out:
# 0    10500000
# 1     3800000
# 2    19000000
# 3    15000000
# 4    17500000
# Name: Price, dtype: int64

# %%
len(y)
# Out:
# 717

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.7753071770785662

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([-1.31341697e+15, -1.35219719e+15, -5.45986682e+13, -6.42018441e+13,
#        -1.59722805e+14])

# %%
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

def find_best_model_using_gridsearchcv(X, y):
    algos = {
        'linear_regression': {
            'model': LinearRegression(),
            'params': {
                'fit_intercept': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1, 2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion': ['squared_error', 'friedman_mse'],
                'splitter': ['best', 'random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X, y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])

# Example usage:
# Assuming X and y are already defined as your features and target variable
result = find_best_model_using_gridsearchcv(X, y)
print(result)
# Out:
#                model    best_score  \
# 0  linear_regression -2.465137e+14
# 1              lasso  4.272485e-01
# 2      decision_tree  7.437449e-01
#
#                                          best_params
# 0                           {'fit_intercept': False}
# 1                {'alpha': 2, 'selection': 'random'}
# 2  {'criterion': 'squared_error', 'splitter': 'ra...

# %%
import numpy as np
def predict_price(location,Area,Bathroom,BHK):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = Area
    x[1] = Bathroom
    x[2] = BHK
    if loc_index >= 0:
        x[loc_index] = 1
    a=np.abs(lr_clf.predict([x])[0])

    print(a)

# %%
predict_price('Yamuna Vihar, Shahdara',800, 1,3)
# Out:
# 6743286.836503681
# C:\Users\RIJUL GULATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predict_price('Abhimanyu Apartments, Vasundhara Enclave',1000, 2, 2)
# Out:
# 23035262.608535253
# C:\Users\RIJUL GULATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predict_price('Alaknanda',1000, 2, 2)
# Out:
# 3102637.6901261546
# C:\Users\RIJUL GULATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df7.columns.tolist()
# Out:
# ['Area',
#  'BHK',
#  'Bathroom',
#  'Parking',
#  'Price',
#  'Transaction',
#  'Per_Sqft',
#  'Abhimanyu Apartments, Vasundhara Enclave',
#  'Abul Fazal Enclave Part-II, Okhla',
#  'Alaknanda',
#  'Amar Colony, Lajpat Nagar',
#  'Andheria Mor, Mehrauli',
#  'Arjun Nagar, Safdarjung Enclave',
#  'Ashirwad Apartments, Dwarka',
#  'Ashirwad Apartments, Dwarka Sector 12',
#  'Balbir Nagar, Shahdara',
#  'Budh Vihar',
#  'Budh Vihar Phase 1',
#  'Chhattarpur',
#  'Chhattarpur Enclave Phase2',
#  'Chittaranjan Park',
#  'Common Wealth Games Village, Commonwealth Games Village 2010',
#  'Commonwealth Games Village 2010',
#  'DDA Flats Block A, Dilshad Garden',
#  'DDA Flats Pocket 3, Narela',
#  'DDA Flats Sector E Pocket 1, Vasant Kunj',
#  'DDA Flats Vasant Kunj, Vasant Kunj',
#  'DDA Flats, Sarita',
#  'DDA Lig Flats, Narela',
#  'DDA MIG Flats Prasad Nagar Phase 2, Prasad Nagar, Karol Bagh',
#  'DLF Capital Greens, Moti Nagar, Kirti Nagar ( 1 km from New Moti Nagar, Kirti Nagar)',
# ...

# %%
df7.columns.tolist();

# %%
X[:2]
# Out:
#      Area  BHK  Bathroom  Parking  Per_Sqft  \
# 0  1350.0    4       4.0      1.0   11291.5
# 1   750.0    2       2.0      1.0   10320.0
#
#    Abhimanyu Apartments, Vasundhara Enclave  \
# 0                                      True
# 1                                     False
#
#    Abul Fazal Enclave Part-II, Okhla  Alaknanda  Amar Colony, Lajpat Nagar  \
# 0                              False      False                      False
# 1                               True      False                      False
#
#    Andheria Mor, Mehrauli  ...  Sunny Valley Apartments, Dwarka  \
# 0                   False  ...                            False
# 1                   False  ...                            False
#
#    The Amaryllis, Karol Bagh  The Leela Sky Villas, Patel Nagar  Uttam Nagar  \
# 0                      False                              False        False
# 1                      False                              False        False
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# Initialize and train the Decision Tree Regressor
dt_clf = DecisionTreeRegressor(random_state=10)
dt_clf.fit(X_train, y_train)

# Evaluate the model
y_pred = dt_clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 175777896219135.8
# R^2 Score: 0.7054638685702601

# %%
import numpy as np
def predict_price(location,Area,Bathroom,BHK):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = Area
    x[1] = Bathroom
    x[2] = BHK
    if loc_index >= 0:
        x[loc_index] = 1

    return np.abs(dt_clf.predict([x])[0])

# %%
predict_price('Abhimanyu Apartments, Vasundhara Enclave',1000, 2, 2)
# Out:
# C:\Users\RIJUL GULATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# np.float64(10500000.0)

# %%
predict_price('Alaknanda',1000, 1, 2)
# Out:
# C:\Users\RIJUL GULATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# np.float64(10500000.0)

# %%
predict_price('Yamuna Vihar, Shahdara',800, 1,3)
# Out:
# C:\Users\RIJUL GULATI\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# np.float64(3300000.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# Initialize and train the XGBRegressor
xgb_reg = XGBRegressor(random_state=10)
xgb_reg.fit(X_train, y_train)

# Evaluate the model
y_pred = xgb_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 108894408981089.53
# R^2 Score: 0.817534863948822

# %%
import numpy as np
def predict_price(location,Area,Bathroom,BHK):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = Area
    x[1] = Bathroom
    x[2] = BHK
    if loc_index >= 0:
        x[loc_index] = 1

    return np.abs(xgb_reg.predict([x])[0]/100000)

# %%
predict_price('Abhimanyu Apartments, Vasundhara Enclave',1000, 2, 1)
# Out:
# np.float32(12.236095)

# %%
predict_price('Yamuna Vihar, Shahdara',800, 3,3)
# Out:
# np.float32(53.692825)

# %%
predict_price('Alaknanda',1000, 4, 4)
# Out:
# np.float32(289.45752)

# %%
import pickle
with open('delhi_house_model.pickle','wb') as f:
    pickle.dump(xgb_reg,f)

# %%
import json
columns={
    'data_columns':[col.lower() for col in X.columns]
}
with open('columns.json',"w") as f:
    f.write(json.dumps(columns))
